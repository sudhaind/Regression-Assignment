# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV

parameter_grid={'criterion':['squared_error', 'friedman_mse','absolute_error', 'poisson'],
                'max_features':['sqrt','log2'],
                'splitter':['best','random']}


grid = GridSearchCV(DecisionTreeRegressor(),parameter_grid,refit=True,verbose=3,n_jobs=1)

# fitting the model for grid search

grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.579 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.681 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.700 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.601 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.598 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.463 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.631 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.553 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.655 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.707 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.628 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.696 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.686 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.726 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.662 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.517 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.718 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.672 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.681 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.748 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.557 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.703 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.746 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.683 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.711 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.614 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.642 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.615 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.669 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.747 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.641 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.685 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.661 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.746 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.465 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.547 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.702 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.588 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.689 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.710 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.551 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.628 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.715 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.613 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.717 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.659 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.773 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.695 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.712 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.706 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.612 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.638 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.662 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.701 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.727 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.310 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.706 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.715 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.627 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.740 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.631 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.736 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.693 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.662 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.697 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.475 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.691 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.571 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.743 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.721 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.606 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.681 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.688 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.658 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.762 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.499 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.674 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.614 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.545 total time=   0.0s
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best_parameter  after tuning
#print(grid.best_params_)
re=grid.cv_results_

print("The R_score value for best parameter {}:",format(grid.best_params_))
# Out:
# The R_score value for best parameter {}: {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'random'}

# %%
table =pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005795      0.003082         0.005038        0.003428
# 1        0.002521      0.002106         0.002780        0.003670
# 2        0.009057      0.002263         0.001004        0.002009
# 3        0.006057      0.001479         0.002510        0.002240
# 4        0.008509      0.003316         0.000648        0.001295
# 5        0.006898      0.003794         0.002384        0.000784
# 6        0.008601      0.002992         0.000000        0.000000
# 7        0.004611      0.003281         0.000408        0.000816
# 8        0.019659      0.004351         0.002007        0.001912
# 9        0.010855      0.002779         0.004665        0.004158
# 10       0.020257      0.002570         0.000000        0.000000
# 11       0.013337      0.004495         0.004979        0.005052
# 12       0.009652      0.000819         0.000303        0.000605
# 13       0.004999      0.003785         0.000000        0.000000
# 14       0.009121      0.000924         0.002067        0.001167
# 15       0.004931      0.005096         0.003548        0.003921
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.792543
# 1   {'criterion': 'squared_error', 'max_features':...           0.598101
# 2   {'criterion': 'squared_error', 'max_features':...           0.707109
# 3   {'criterion': 'squared_error', 'max_features':...           0.661647
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.747938
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.711380
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.746802
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.465446
# 8   {'criterion': 'absolute_error', 'max_features'...           0.709797
# 9   {'criterion': 'absolute_error', 'max_features'...           0.716983
# 10  {'criterion': 'absolute_error', 'max_features'...           0.706188
# 11  {'criterion': 'absolute_error', 'max_features'...           0.727086
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.740296
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.696653
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.721144
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.761727
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.579204           0.681075           0.700490
# 1            0.463440           0.631363           0.553412
# 2            0.627992           0.695860           0.686310
# 3            0.517324           0.717631           0.672474
# 4            0.556651           0.703208           0.745567
# 5            0.614046           0.641595           0.614999
# 6            0.641133           0.684895           0.661409
# 7            0.547006           0.701624           0.588471
# 8            0.550775           0.628042           0.714834
# 9            0.659078           0.772944           0.695387
# 10           0.611939           0.638466           0.662401
# 11           0.310159           0.705720           0.714768
# 12           0.630701           0.735997           0.693079
# 13           0.474587           0.691110           0.570513
# 14           0.605672           0.681375           0.687710
# 15           0.499044           0.674379           0.614109
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.601131         0.670889        0.076226                6
# 1            0.654910         0.580245        0.067632               16
# 2            0.725951         0.688644        0.033072                4
# 3            0.681436         0.650102        0.069001               10
# 4            0.683428         0.687359        0.069870                5
# 5            0.669339         0.650272        0.036687                9
# 6            0.746128         0.696073        0.043414                2
# 7            0.689337         0.598377        0.088703               15
# 8            0.612862         0.643262        0.062063               11
# 9            0.711924         0.711263        0.036913                1
# 10           0.701013         0.664002        0.036096                8
# 11           0.627252         0.616997        0.157357               14
# 12           0.662195         0.692454        0.042224                3
# 13           0.742696         0.635112        0.098426               12
# 14           0.657747         0.670730        0.038326                7
# 15           0.545421         0.618936        0.093022               13

# %%
age_input=int(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=int(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:54
# BMI:23
# Children:2
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction) )
# Out:
# Future_Prediction=[8804.83945]
# C:\Users\hema\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
